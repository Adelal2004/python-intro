# %% [markdown]
# # Notebook 1: Datatyper, aritmetiske operasjoner, kommentarer og print()
#
# **Fag:** Konseptutvikling og programmering
# **Linje:** Informasjonsteknologi og medieproduksjon, Vg1
#
# ## Læringsmål
# Etter denne notebooken skal du kunne:
# - Skrive kommentarer i Python-kode
# - Bruke `print()`-funksjonen til å skrive ut tekst og tall
# - Kjenne igjen og bruke de vanligste datatypene (heltall, flyttall, tekst, boolsk verdi)
# - Opprette og bruke variabler
# - Utføre aritmetiske operasjoner (regneoperasjoner) i Python
#
# ---
#
# Kjør hver kodecelle med **Shift + Enter** for å se hva som skjer. Prøv gjerne å endre litt på koden underveis!

# %% [markdown]
# ## 1.1 Kommentarer
#
# Når vi skriver kode ønsker vi ofte å forklare hva koden gjør, både for oss selv og andre som skal lese den senere. Da bruker vi **kommentarer**. Kommentarer blir ikke kjørt som kode av Python.
#
# Det finnes to måter å skrive kommentarer på i Python:
#
# **1. Med hash (`#`)**
# Alt som står etter `#` på samme linje blir ignorert av Python.
#
# **2. Med trippel anførselstegn (`"""`)**
# Brukes når du vil kommentere over flere linjer samtidig.

# %%
# Dette er en kommentar - Python leser ikke denne linjen som kode
print("Hei verden")  # Dette er også en kommentar, etter koden på samme linje

"""
Dette er en kommentar
som strekker seg
over flere linjer
"""

# %% [markdown]
# ## 1.2 print()-funksjonen
#
# `print()` er en av de mest brukte funksjonene i Python. Den skriver ut det du ber om i konsollen (output-feltet under kodecellen).
#
# `print()` kan ta imot ett eller flere argumenter (verdier). Dersom du vil skrive ut flere ting på samme linje, skiller du dem med komma.

# %%
print("Hallo verden")       # Skriver ut tekst
print(42)                   # Skriver ut et tall
print("Jeg er", 16, "år")   # Flere argumenter atskilt med komma

# %% [markdown]
# ### 🔧 Oppgave 1.2.1
# Bruk `print()` til å skrive ut teksten **"Jeg lærer Python på IT-linja!"**

# %%
print("Jeg lærer Python på IT-linja!")

# %% [markdown]
# ### 🔧 Oppgave 1.2.2
# Lag et program som skriver ut navnet ditt og alderen din på samme linje, for eksempel:
# `Jeg heter Kari og er 16 år.`
#
# Husk å bruke komma mellom argumentene i `print()`.

# %%
print("Jeg heter Abdullah og er", 22, "år.")

# %% [markdown]
# ## 1.3 Datatyper
#
# I Python finnes det flere datatyper. De mest brukte er:
#
# | Datatype | Beskrivelse | Eksempel |
# |---|---|---|
# | **int** (heltall) | Hele tall, uten desimaler | `5`, `-3`, `200` |
# | **float** (flyttall) | Tall med desimaler | `3.14`, `-0.5` |
# | **str** (streng/tekst) | Tekst, skrives i anførselstegn | `"Hei"`, `"Python"` |
# | **bool** (boolsk verdi) | Sann/usann | `True`, `False` |
# | **list** (liste) | Samling av flere verdier | `[1, 2, 3]` |
#
# Vi kommer tilbake til lister i en senere notebook.

# %% [markdown]
# ## 1.4 Variabler
#
# En **variabel** er et navn vi gir til en verdi, slik at vi kan bruke verdien senere i programmet. Vi oppretter en variabel med likhetstegn (`=`).
#
# `variabelnavn = verdi`
#
# Det som står til høyre for likhetstegnet blir lagt inn i variabelen på venstre side.

# %%
a = 10
b = 3.5
c = "Hei"

# Skriver ut variablene
print(a)
print(b)
print(c)
# Out:
# 10
# 3.5
# Hei

# %% [markdown]
# Vi kan sjekke hvilken datatype en variabel har med funksjonen `type()`.

# %%
print(type(a))
print(type(b))
print(type(c))  
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 print(type(a))
#       2 print(type(b))
#       3 print(type(c))
# ----> 4 print(type(d))
#
# NameError: name 'd' is not defined

# %% [markdown]
# Vi kan også gjøre om (konvertere) mellom datatyper med funksjonene `int()`, `float()` og `str()`.
#
# | Funksjon | Gjør om til | Eksempel |
# |---|---|---|
# | `int()` | heltall | `int(2.718)` gir `2` |
# | `float()` | flyttall | `float(3)` gir `3.0` |
# | `str()` | tekst | `str(34)` gir `"34"` |

# %%
e = int(2.718)     # gjør om til heltall (kutter desimalene)
print(e)

f = float(3)       # gjør om til flyttall
print(f)

g = str(34)        # gjør om til tekst
print(g)
print(type(g))

# %% [markdown]
# ### 🔧 Oppgave 1.4.1
# Lag et program der du:
# 1. Lagrer et heltall i variabelen `a`
# 2. Lagrer et flyttall i variabelen `b`
# 3. Lagrer en tekststreng i variabelen `c`
# 4. Skriver ut alle tre med `print()`, og legger til en kommentar som forklarer hva du gjør

# %%
# Lager tre variabler med forskjellige datatyper
a = 10
b = 3.5
c = "Hei"

print(a)
print(b)
print(c)
# Out:
# 10
# 3.5
# Hei

# %% [markdown]
# ## 1.5 Aritmetiske operasjoner
#
# Python kan brukes som en avansert kalkulator. Her er de vanligste regneoperatorene:
#
# | Operator | Betydning | Eksempel |
# |---|---|---|
# | `+` | Addisjon | `4 + 2` → `6` |
# | `-` | Subtraksjon | `4 - 2` → `2` |
# | `*` | Multiplikasjon | `4 * 2` → `8` |
# | `/` | Divisjon | `4 / 2` → `2.0` |
# | `**` | Eksponent (opphøyd i) | `4 ** 2` → `16` |
# | `//` | Heltallsdivisjon | `7 // 2` → `3` |
# | `%` | Modulo (rest ved divisjon) | `7 % 2` → `1` |

# %%
a = 4
b = 2.718

print(a + b)   # Addisjon
print(a - b)   # Subtraksjon
print(a * b)   # Multiplikasjon
print(a / b)   # Divisjon
print(a ** 2)  # Eksponent
print(a % b)   # Modulus (rest ved divisjon)
# Out:
# 6.718
# 1.282
# 10.872
# 1.4716703458425313
# 16
# 1.282

# %% [markdown]
# **Heltallsdivisjon (`//`)** forteller oss hvor mange hele ganger et tall går opp i et annet.
# **Modulo (`%`)** forteller oss hva som er *igjen* (resten) etter en slik divisjon.

# %%
print(7 // 2)   # Hvor mange hele ganger går 2 opp i 7? Svar: 3
print(7 % 2)    # Hva blir resten? Svar: 1
# Out:
# 3
# 1

# %% [markdown]
# ### 💡 Eksempel: Areal av en skjerm
# Vi kan bruke variabler og regneoperatorer til å regne ut praktiske ting, for eksempel arealet av en dataskjerm.

# %%
bredde = 34.5   # cm
hoyde = 19.4    # cm

areal = bredde * hoyde
print("Arealet av skjermen er", areal, "kvadratcentimeter")
# Out:
# Arealet av skjermen er 669.3 kvadratcentimeter

# %% [markdown]
# ### 🔧 Oppgave 1.5.1
# Lag et program der du definerer `a = 12` og `b = 5`. Skriv ut summen, differansen, produktet og resultatet av divisjon mellom `a` og `b`, hver med en forklarende tekst (bruk `print()` med komma).

# %%
# Lager variabelen x med verdien 8
x = 8

# Lager variabelen y med verdien 3
y = 3

# Deler x på y
print(x / y)

# Heltallsdivisjon av x på y
print(x // y)

# Skriver resten etter divisjon
print(x % y)

# Regner ut x opphøyd i y
print(x ** y)
# Out:
# 2.6666666666666665
# 2
# 2
# 512

# %% [markdown]
# ### 🔧 Oppgave 1.5.2
# En fil er 2450 MB stor. Skriv et program som regner ut hvor mange hele gigabyte (GB) filen er, og hvor mange MB som er "til overs" (husk: 1 GB = 1000 MB).
#
# *Tips: bruk heltallsdivisjon `//` og modulo `%`.*

# %%
fil_storrelse = 2450

gb = fil_storrelse // 1000
mb = fil_storrelse % 1000

print("Hele GB:", gb)
print("MB til overs:", mb)
# Out:
# Hele GB: 2
# MB til overs: 450

# %% [markdown]
# ### 🔧 Oppgave 1.5.3 – Regnestykker
# Skriv Python-kode som regner ut svaret på hvert av regnestykkene under, og skriv resultatene ut i konsollen.
#
# a) $3 + 5 \cdot 2$
# b) $(9 - 2) \cdot 4$
# c) $2^{10}$
# d) $17 \mathbin{\%} 5$ (resten ved heltallsdivisjon)

# %%
print(3 + 5 * 2)
print((9 - 2) * 4)
print(2 ** 10)
print(17 % 5)
# Out:
# 13
# 28
# 1024
# 2

# %% [markdown]
# ### 🔧 Oppgave 1.5.4 – Test kunnskapen din
# Skriv en kort kommentar (med `#`) over hver linje kode under som forklarer hva linjen gjør. Kjør deretter cellen og se om resultatet stemmer med det du forventet.

# %%
# Lager variabelen x med verdien 8
x = 8

# Lager variabelen y med verdien 3
y = 3

# Deler x på y
print(x / y)

# Heltallsdivisjon av x på y
print(x // y)

# Finner resten etter divisjon
print(x % y)

# Regner ut x opphøyd i y
print(x ** y)
# Out:
# 2.6666666666666665
# 2
# 2
# 512

# %% [markdown]
# ---
# ## 1.6 Avsluttende oppgaver
#
# Her finner du flere oppgaver, delt inn i **enkel**, **middels** og **vanskelig**. Jobb deg gjennom i din egen takt - du trenger ikke gjøre alle!

# %% [markdown]
# ### 🟢 Enkelt nivå
#
# **Oppgave A**
# Lag variabler for navnet, alderen og høyden din (i cm). Skriv dem ut med `print()` og en forklarende tekst, for eksempel: `Navn: Kari, Alder: 16, Høyde: 170`.
#
# **Oppgave B**
# Lag to variabler `a = 45` og `b = 8`. Skriv ut resultatet av `a + b`, `a - b`, `a * b` og `a / b`, hver på sin egen linje med `print()`.

# %%
navn = "Abdullah"
alder = 21
hoyde = 175

print("Navn:", navn, "Alder:", alder, "Høyde:", hoyde)
# Out:
# Navn: Abdullah Alder: 21 Høyde: 175

# %%
a = 45
b = 8

print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 53
# 37
# 360
# 5.625

# %% [markdown]
# ### 🟡 Middels nivå
#
# **Oppgave C**
# En video er 3672 sekunder lang. Skriv et program som regner ut hvor mange hele minutter og hvor mange sekunder "til overs" videoen er (bruk `//` og `%`).
#
# **Oppgave D**
# Lag variablene `pris = "299"` (som tekst) og `mva_prosent = 25`. Gjør om `pris` til riktig datatype, og regn ut og skriv ut totalprisen inkludert mva.

# %%
sekunder = 3672

minutter = sekunder // 60
rest = sekunder % 60

print("Minutter:", minutter)
print("Sekunder til overs:", rest)
# Out:
# Minutter: 61
# Sekunder til overs: 12

# %%
pris = "299"
mva_prosent = 25

pris = int(pris)
totalpris = pris + pris * mva_prosent / 100

print("Totalpris med mva:", totalpris)
# Out:
# Totalpris med mva: 373.75

# %% [markdown]
# ### 🔴 Vanskelig nivå (utfordrende)
#
# **Oppgave E**
# Skriv et program som regner ut gjennomsnittet av tre selvvalgte tall (uten å bruke en liste), og runder svaret av til 2 desimaler med `round()`.
#
# **Oppgave F**
# En skjerm har oppløsning 1920 x 1080 piksler. Skriv et program som regner ut hvor mange piksler skjermen har totalt, og skriver svaret ut med tusenskilletegn, for eksempel ved å bruke `print(f"{piksler:,}")`.

# %%
tall1 = 10
tall2 = 15
tall3 = 22

gjennomsnitt = (tall1 + tall2 + tall3) / 3

print(round(gjennomsnitt, 2))
# Out:
# 15.67

# %%
bredde = 1920
hoyde = 1080

piksler = bredde * hoyde

print(f"{piksler:,}")
# Out:
# 2,073,600

# %% [markdown]
# ---
# ## Oppsummering
# - Kommentarer (`#` og `"""`) brukes til å forklare koden, og kjøres ikke av Python
# - `print()` skriver ut tekst og verdier i konsollen
# - De vanligste datatypene er `int`, `float`, `str` og `bool`
# - Variabler opprettes med `=` og kan endre datatype med `int()`, `float()` og `str()`
# - De aritmetiske operatorene er `+ - * / ** // %`
#
# Neste notebook: **Å lese feilmeldinger** ➡️
